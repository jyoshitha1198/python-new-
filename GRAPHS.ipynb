# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoshitha1198/python-new-/blob/module-4/GRAPHS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LINE DIAGRAMS

# %%
##line diagram from([0,15])&([0,450])
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 15])
ypoints = np.array([0, 450])

plt.plot(xpoints, ypoints)
plt.show()

# %%
## line diagram from ([1,5])to ([8,10])
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([5, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# MARKING PLOTS

# %% [markdown]
# (using circle"o")

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5,10,15,20,25])

plt.plot(ypoints, marker = 'o')
plt.show()

# %% [markdown]
# using "*"=star

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %% [markdown]
# using "^"=triangle up

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 4, 6, 8])

plt.plot(ypoints, marker = '^')
plt.show()

# %% [markdown]
# using "D"=diamond

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 6, 9, 12,15])

plt.plot(ypoints, marker = 'D')
plt.show()

# %% [markdown]
# usinf "H"=hexagon

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 6, 9, 12,15])

plt.plot(ypoints, marker = 'H')
plt.show()

# %% [markdown]
# USING A DOTTED LINE

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,13,25,30,42])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %% [markdown]
# USING A DASHED LINE

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([12,23,43,56,76])

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %% [markdown]
# USING COLOURS

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4, 8, 15, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4,9,12,15,25])

plt.plot(ypoints, color = 'y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,12,22,32,42])

plt.plot(ypoints, color = 'b')
plt.show()

# %% [markdown]
# THICK LINE

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '30.5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([4, 8, 12, 30])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# LABELS

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([340, 350, 360, 370, 380, 390, 400, 410, 420, 430])

plt.plot(x, y)

plt.xlabel("books sold")
plt.ylabel("books didnt soled")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# GRID

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.grid()
plt.show()

# %% [markdown]
# using grind only on x axis

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# using grid on y axis

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# BAR GRAPH

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([5,18, 25, 46])

plt.bar(x,y)
plt.show()

# %% [markdown]
# HORIZANTAL GRAPH

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([6, 18, 54, 162])

plt.barh(x, y)
plt.show()

# %% [markdown]
# BAR COLOR

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "black")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "brown")
plt.show()

# %% [markdown]
# BAR HEIGHT

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.02)
plt.show()

# %% [markdown]
# HISTOGRAM

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(150, 20, 350)

plt.hist(x)
plt.show()

# %%
PIE CHARTS

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15,35,56])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15,34])
mylabels = ["horror", "thriller", "rom-com", "Drama","comedy"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 55, 15,34])
mylabels = ["horror", "thriller", "rom-com", "Drama","comedy"]

plt.pie(y, labels = mylabels, startangle = 60)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15,34])
mylabels = ["horror", "thriller", "rom-com", "drama","comedy"]
myexplode = [0.0, 0, 2, 0,0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15,34])
mylabels = ["horror", "thriller", "rom-com", "Drama","comedy"]
myexplode = [0.0, 2, 0, 0,0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15,34])
mylabels = ["horror", "thriller", "rom-com", "Drama","comedy"]
mycolors = ["black", "hotpink", "b", "g","yellow"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15,34])
mylabels = ["horror", "thriller", "rom-com", "Drama","comedy"]
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15,44])
mylabels = ["horror", "thriller", "rom-com", "Drama","comedy"]
plt.pie(y, labels = mylabels)
plt.legend(title = "genre:")
plt.show()

# %% [markdown]
# SCATTER

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# SUB PLOT

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([4, 9, 2, 11])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 50, 100, 150])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()
